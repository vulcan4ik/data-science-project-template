# %%
import numpy as np
import pandas as pd
import sklearn

print(f"NumPy: {np.__version__}")  # Должно быть ~1.26.x
print(f"Pandas: {pd.__version__}")  # Должно быть ~2.2.x
print(f"Scikit-learn: {sklearn.__version__}")  # Должно быть ~1.5.x
# Out:
# NumPy: 1.26.4
# Pandas: 2.3.3
# Scikit-learn: 1.7.2

# %%
import psycopg2 as pg2
from sqlalchemy import create_engine, text

# Через psycopg2
con = pg2.connect(
    host='postgres',  # имя сервиса из docker-compose
    user='postgres',
    password='password',
    database='postgres'
)
print("✓ psycopg2 подключение успешно")

# Через SQLAlchemy
engine = create_engine('postgresql://postgres:password@postgres:5432/postgres')
with engine.begin() as conn:
    result = conn.execute(text('SELECT version()'))
    version = result.fetchone()[0]
    print("✓ SQLAlchemy подключение успешно")
    print(f"PostgreSQL: {version[:50]}...")

con.close()
# Out:
# ✓ psycopg2 подключение успешно
# ✓ SQLAlchemy подключение успешно
# PostgreSQL: PostgreSQL 10.23 on x86_64-pc-linux-musl, compiled...
